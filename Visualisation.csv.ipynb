# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df=pd.read_csv('abcs.csv',header=None)

# %%
df
# Out:
#        0    1    2    3       4
# 0    NaN    a    b    c       d
# 1    0.0   93   91  184   green
# 2    2.0   86   93  179  orange
# 3    4.0   88   85  173     red
# 4    6.0   82   80  162     red
# 5    8.0  600  600  600     600
# 6   10.0  600  600  600     600
# 7   12.0  600  600  600     600
# 8   14.0  600  600  600     600
# 9   16.0  600  600  600     600
# 10  18.0  600  600  600     600

# %%
df.rename(columns={0:'zero',1:'one',2:'two',3:'three',4:'four'},inplace=True)

# %%
df
# Out:
#     zero  one  two three    four
# 0    NaN    a    b     c       d
# 1    0.0   93   91   184   green
# 2    2.0   86   93   179  orange
# 3    4.0   88   85   173     red
# 4    6.0   82   80   162     red
# 5    8.0  600  600   600     600
# 6   10.0  600  600   600     600
# 7   12.0  600  600   600     600
# 8   14.0  600  600   600     600
# 9   16.0  600  600   600     600
# 10  18.0  600  600   600     600

# %%
df.replace(method='bfill',inplace=True)

# %%
df
# Out:
#     zero  one  two three    four
# 0    NaN    a    b     c       d
# 1    0.0   93   91   184   green
# 2    2.0   86   93   179  orange
# 3    4.0   88   85   173     red
# 4    6.0   82   80   162     red
# 5    8.0  600  600   600     600
# 6   10.0  600  600   600     600
# 7   12.0  600  600   600     600
# 8   14.0  600  600   600     600
# 9   16.0  600  600   600     600
# 10  18.0  600  600   600     600

# %%
ar= np.random.normal(100,2,11)

# %%
ar.sort()

# %%
ar
# Out:
# array([ 97.61205088,  97.6230436 ,  98.85914041,  99.0075969 ,
#         99.0147711 ,  99.34397939,  99.94103829, 100.39425265,
#        101.30641969, 101.64212622, 102.25900313])

# %%
df['five']=ar.round(2)

# %%
df
# Out:
#     zero  one  two three    four    five
# 0    NaN    a    b     c       d   97.61
# 1    0.0   93   91   184   green   97.62
# 2    2.0   86   93   179  orange   98.86
# 3    4.0   88   85   173     red   99.01
# 4    6.0   82   80   162     red   99.01
# 5    8.0  600  600   600     600   99.34
# 6   10.0  600  600   600     600   99.94
# 7   12.0  600  600   600     600  100.39
# 8   14.0  600  600   600     600  101.31
# 9   16.0  600  600   600     600  101.64
# 10  18.0  600  600   600     600  102.26

# %%
df.plot.area()
# Out:
# <Axes: >

# %%
df.plot.line()
# Out:
# <Axes: >

# %%
df['zero'].plot.line()
# Out:
# <Axes: >

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
df.plot.bar('zero')
# Out:
# <Axes: xlabel='zero'>

# %%
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.hist(bins=2) #bins divide the cell here 2 means divide into two
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.max()
# Out:
# zero       18.0
# one           a
# two           b
# three         c
# four        red
# five     102.26
# dtype: object

# %%
df.min()
# Out:
# zero       0.0
# one        600
# two        600
# three      162
# four       600
# five     97.61
# dtype: object

# %%
np.linspace(0,18,3)
# Out:
# array([ 0.,  9., 18.])

# %%
df['zero'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sn.distplot(df['zero'])
# Out:
# <Axes: xlabel='zero', ylabel='Density'>

# %%
df['zero'].plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
df.to_csv('visulisation.csv')

# %%
df
# Out:
#     zero  one  two three    four    five
# 0    NaN    a    b     c       d   97.61
# 1    0.0   93   91   184   green   97.62
# 2    2.0   86   93   179  orange   98.86
# 3    4.0   88   85   173     red   99.01
# 4    6.0   82   80   162     red   99.01
# 5    8.0  600  600   600     600   99.34
# 6   10.0  600  600   600     600   99.94
# 7   12.0  600  600   600     600  100.39
# 8   14.0  600  600   600     600  101.31
# 9   16.0  600  600   600     600  101.64
# 10  18.0  600  600   600     600  102.26

# %%
pwd
# Out:
# 'C:\\Users\\hp\\Documents'

# %%
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'abc.csv',
#  'abcs.csv',
#  'Data Science Assignment.ipynb',
#  'First.ipynb',
#  'krishna.png',
#  'My Music',
#  'My Pictures',
#  'My Videos',
#  'numpy and pandas.ipynb',
#  'numpy applications.ipynb',
#  'pandas 2 excelr.ipynb',
#  'Practice dataframe.ipynb',
#  'practice image.ipynb',
#  'q12.csv',
#  'Untitled.ipynb',
#  'Visualisation.csv.ipynb',
#  'visulisation.csv']

# %%
df.plot.box()
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#             zero        five
# count  10.000000   11.000000
# mean    9.000000   99.726364
# std     6.055301    1.546520
# min     0.000000   97.610000
# 25%     4.500000   98.935000
# 50%     9.000000   99.340000
# 75%    13.500000  100.850000
# max    18.000000  102.260000

# %%
np.quantile(df['zero'],0.25)
# Out:
# nan

# %%
np.quantile(df['zero'],0.5)
# Out:
# nan

# %%
np.quantile(df['zero'],0.75)
# Out:
# nan

# %%
np.linspace(0,18,5)
# Out:
# array([ 0. ,  4.5,  9. , 13.5, 18. ])

# %%
df['zero'].plot.box()
# Out:
# <Axes: >

# %%
q1=np.quantile(df['zero'],0.25)
q3=np.quantile(df['zero'],0.75)

# %%
iqr=q3-q1

# %%
lb=q1-1.5*iqr

# %%
lb
# Out:
# nan

# %%
ub=q3+1.5*iqr

# %%
ub
# Out:
# nan

# %%
df
# Out:
#     zero  one  two three    four    five
# 0    NaN    a    b     c       d   97.61
# 1    0.0   93   91   184   green   97.62
# 2    2.0   86   93   179  orange   98.86
# 3    4.0   88   85   173     red   99.01
# 4    6.0   82   80   162     red   99.01
# 5    8.0  600  600   600     600   99.34
# 6   10.0  600  600   600     600   99.94
# 7   12.0  600  600   600     600  100.39
# 8   14.0  600  600   600     600  101.31
# 9   16.0  600  600   600     600  101.64
# 10  18.0  600  600   600     600  102.26

# %%
plt.plot(df['zero'])

# %%
plt.plot(df['zero'],df['five'])

# %%
x=np.linspace(2,12,20)

# %%
y=x**2+1

# %%
plt.plot(x,y)

# %%
x=np.linspace(-2,12,20)

# %%
y=x**2+1

# %%
plt.plot(x,y)

# %%
plt.plot(x,y,'r*--')

# %%
plt.plot(x,y,'r*-')

# %%
plt.plot(x,y,'r*:')

# %%
plt.plot(x,y,'r*:',ms=10) #marker size

# %%
plt.plot(x,y)
plt.plot(x,3*x**2+1)

# %%
plt.plot(x,y,label='fisrt')
plt.plot(x,3*x**2+1,label='second')
plt.axvline(x=0)
plt.axhline(y=100)
plt.legend()

# %%
xx=np.linspace(-1,12,20)

# %%
plt.plot(x,x**2+1)
plt.plot(xx,xx**2+1)

# %%
plt.fill_between(xx,xx**2+1)
plt.plot(x,x**2+1)

# %%
#y=x**2+1
#x=np.linspace(-2,12,20)

# %%
y=x**2+1

# %%
noise=np.random.normal(0,2,20)

# %%
y + noise
# Out:
# array([  6.34033523,   4.57032258,   2.56402258,   0.15348887,
#          2.77818481,   3.85577983,   4.58255486,  14.62401656,
#         16.74365898,  20.90537045,  27.7161156 ,  34.96844578,
#         47.10263009,  56.1020505 ,  71.59072826,  86.42937561,
#         98.51722914, 113.38410612, 131.07540085, 144.966184  ])

# %%
y+noise
# Out:
# array([  6.34033523,   4.57032258,   2.56402258,   0.15348887,
#          2.77818481,   3.85577983,   4.58255486,  14.62401656,
#         16.74365898,  20.90537045,  27.7161156 ,  34.96844578,
#         47.10263009,  56.1020505 ,  71.59072826,  86.42937561,
#         98.51722914, 113.38410612, 131.07540085, 144.966184  ])

# %%
plt.plot(x,y)
plt.scatter(x,y+noise)

# %%
plt.subplot(3,2,1)
plt.plot(x,y)

plt.subplot(3,2,2)
plt.plot(x,y)

plt.subplot(3,2,3)
plt.plot(x,y)

# %%
plt.figure(figsize=(20,20))
plt.subplot(3,2,1)
plt.plot(x,y)
plt.title('first')
plt.subplot(3,2,2)
plt.plot(x,y)

plt.subplot(3,2,3)
plt.plot(x,y)
